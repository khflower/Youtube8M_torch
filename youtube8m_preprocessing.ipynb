# %% [markdown]
# ### 경로 설정

# %%
import os

# 변경할 디렉토리 경로
new_path = '/content/drive/MyDrive/youtube'

# 디렉토리 변경
os.chdir(new_path)

# 변경된 디렉토리 출력
print("현재 경로:", os.getcwd())
# Out:
# 현재 경로: /content/drive/MyDrive/youtube

# %% [markdown]
# ### 데이터 다운로드

# %%
# !curl data.yt8m.org/download.py | partition=2/video/validate mirror=asia python
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateTx.tfrecord 100.4%Succesfully downloaded validate2813.tfrecord 1248421 bytes.
# Successfully downloaded validate2813.tfrecord
#
#
# Downloading: validate2097.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateHZ.tfrecord 100.2%Succesfully downloaded validate2097.tfrecord 1333242 bytes.
# Successfully downloaded validate2097.tfrecord
#
#
# Downloading: validate2435.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateNr.tfrecord 100.4%Succesfully downloaded validate2435.tfrecord 1281382 bytes.
# Successfully downloaded validate2435.tfrecord
#
#
# Downloading: validate1349.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatevV.tfrecord 100.6%Succesfully downloaded validate1349.tfrecord 1319087 bytes.
# Successfully downloaded validate1349.tfrecord
#
#
# Downloading: validate1491.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateyd.tfrecord 100.3%Succesfully downloaded validate1491.tfrecord 1257920 bytes.
# Successfully downloaded validate1491.tfrecord
#
#
# Downloading: validate1669.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateA5.tfrecord 100.2%Succesfully downloaded validate1669.tfrecord 1333187 bytes.
# Successfully downloaded validate1669.tfrecord
#
#
# Downloading: validate1592.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatezQ.tfrecord 100.6%Succesfully downloaded validate1592.tfrecord 1319087 bytes.
# Successfully downloaded validate1592.tfrecord
#
#
# Downloading: validate1118.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatesc.tfrecord 100.5%Succesfully downloaded validate1118.tfrecord 1385057 bytes.
# Successfully downloaded validate1118.tfrecord
#
#
# Downloading: validate3472.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate4a.tfrecord 100.3%Succesfully downloaded validate3472.tfrecord 1347410 bytes.
# Successfully downloaded validate3472.tfrecord
#
#
# Downloading: validate2760.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateSG.tfrecord 100.3%Succesfully downloaded validate2760.tfrecord 1436938 bytes.
# Successfully downloaded validate2760.tfrecord
#
#
# Downloading: validate3563.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate5D.tfrecord 100.1%Succesfully downloaded validate3563.tfrecord 1488725 bytes.
# Successfully downloaded validate3563.tfrecord
#
#
# Downloading: validate1331.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatevD.tfrecord 100.3%Succesfully downloaded validate1331.tfrecord 1380351 bytes.
# Successfully downloaded validate1331.tfrecord
#
#
# Downloading: validate0757.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatemn.tfrecord 100.3%Succesfully downloaded validate0757.tfrecord 1314414 bytes.
# Successfully downloaded validate0757.tfrecord
#
#
# Downloading: validate3503.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate4F.tfrecord 100.5%Succesfully downloaded validate3503.tfrecord 1394523 bytes.
# Successfully downloaded validate3503.tfrecord
#
#
# Downloading: validate1467.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatexP.tfrecord 100.1%Succesfully downloaded validate1467.tfrecord 1210727 bytes.
# Successfully downloaded validate1467.tfrecord
#
#
# Downloading: validate1079.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validaterz.tfrecord 100.0%Succesfully downloaded validate1079.tfrecord 1408607 bytes.
# Successfully downloaded validate1079.tfrecord
#
#
# Downloading: validate2838.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateTW.tfrecord 100.4%Succesfully downloaded validate2838.tfrecord 1281472 bytes.
# Successfully downloaded validate2838.tfrecord
#
#
# Downloading: validate0847.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatenP.tfrecord 100.6%Succesfully downloaded validate0847.tfrecord 1262472 bytes.
# Successfully downloaded validate0847.tfrecord
#
#
# Downloading: validate1674.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateBa.tfrecord 100.4%Succesfully downloaded validate1674.tfrecord 1403918 bytes.
# Successfully downloaded validate1674.tfrecord
#
#
# Downloading: validate3290.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate1e.tfrecord 100.5%Succesfully downloaded validate3290.tfrecord 1394438 bytes.
# Successfully downloaded validate3290.tfrecord
#
#
# Downloading: validate2161.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateI1.tfrecord 100.3%Succesfully downloaded validate2161.tfrecord 1469873 bytes.
# Successfully downloaded validate2161.tfrecord
#
#
# Downloading: validate2404.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateMW.tfrecord 100.2%Succesfully downloaded validate2404.tfrecord 1177880 bytes.
# Successfully downloaded validate2404.tfrecord
#
#
# Downloading: validate2651.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQV.tfrecord 100.0%Succesfully downloaded validate2651.tfrecord 1286057 bytes.
# Successfully downloaded validate2651.tfrecord
#
#
# Downloading: validate0911.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateoR.tfrecord 100.5%Succesfully downloaded validate0911.tfrecord 1418107 bytes.
# Successfully downloaded validate0911.tfrecord
#
#
# Downloading: validate3647.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate6Z.tfrecord 100.4%Succesfully downloaded validate3647.tfrecord 1337901 bytes.
# Successfully downloaded validate3647.tfrecord
#
#
# Downloading: validate2619.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQp.tfrecord 100.2%Succesfully downloaded validate2619.tfrecord 1455771 bytes.
# Successfully downloaded validate2619.tfrecord
#
#
# Downloading: validate3513.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate4P.tfrecord 100.1%Succesfully downloaded validate3513.tfrecord 1488719 bytes.
# Successfully downloaded validate3513.tfrecord
#
#
# Downloading: validate2849.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateT7.tfrecord 100.4%Succesfully downloaded validate2849.tfrecord 1370848 bytes.
# Successfully downloaded validate2849.tfrecord
#
#
# Downloading: validate2390.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateMI.tfrecord 100.5%Succesfully downloaded validate2390.tfrecord 1361553 bytes.
# Successfully downloaded validate2390.tfrecord
#
#
# Downloading: validate1828.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDE.tfrecord 100.5%Succesfully downloaded validate1828.tfrecord 1385079 bytes.
# Successfully downloaded validate1828.tfrecord
#
#
# Downloading: validate2845.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateT3.tfrecord 100.0%Succesfully downloaded validate2845.tfrecord 1408655 bytes.
# Successfully downloaded validate2845.tfrecord
#
#
# Downloading: validate2807.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateTr.tfrecord 100.1%Succesfully downloaded validate2807.tfrecord 1399218 bytes.
# Successfully downloaded validate2807.tfrecord
#
#
# Downloading: validate2423.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateNf.tfrecord 100.4%Succesfully downloaded validate2423.tfrecord 1304933 bytes.
# Successfully downloaded validate2423.tfrecord
#
#
# Downloading: validate0182.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatec6.tfrecord 100.5%Succesfully downloaded validate0182.tfrecord 1295483 bytes.
# Successfully downloaded validate0182.tfrecord
#
#
# Downloading: validate1337.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatevJ.tfrecord 100.3%Succesfully downloaded validate1337.tfrecord 1436883 bytes.
# Successfully downloaded validate1337.tfrecord
#
#
# Downloading: validate2756.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateSC.tfrecord 100.5%Succesfully downloaded validate2756.tfrecord 1272013 bytes.
# Successfully downloaded validate2756.tfrecord
#
#
# Downloading: validate3005.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateWD.tfrecord 100.5%Succesfully downloaded validate3005.tfrecord 1361451 bytes.
# Successfully downloaded validate3005.tfrecord
#
#
# Downloading: validate2187.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateJr.tfrecord 100.6%Succesfully downloaded validate2187.tfrecord 1319148 bytes.
# Successfully downloaded validate2187.tfrecord
#
#
# Downloading: validate1854.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateD4.tfrecord 100.6%Succesfully downloaded validate1854.tfrecord 1262553 bytes.
# Successfully downloaded validate1854.tfrecord
#
#
# Downloading: validate0568.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatejk.tfrecord 100.4%Succesfully downloaded validate0568.tfrecord 1337879 bytes.
# Successfully downloaded validate0568.tfrecord
#
#
# Downloading: validate1071.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validaterr.tfrecord 100.5%Succesfully downloaded validate1071.tfrecord 1394451 bytes.
# Successfully downloaded validate1071.tfrecord
#
#
# Downloading: validate1292.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateu0.tfrecord 100.4%Succesfully downloaded validate1292.tfrecord 1337930 bytes.
# Successfully downloaded validate1292.tfrecord
#
#
# Downloading: validate3551.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate5r.tfrecord 100.3%Succesfully downloaded validate3551.tfrecord 1380391 bytes.
# Successfully downloaded validate3551.tfrecord
#
#
# Downloading: validate3419.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate3j.tfrecord 100.3%Succesfully downloaded validate3419.tfrecord 1535876 bytes.
# Successfully downloaded validate3419.tfrecord
#
#
# Downloading: validate1833.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDJ.tfrecord 100.3%Succesfully downloaded validate1833.tfrecord 1502775 bytes.
# Successfully downloaded validate1833.tfrecord
#
#
# Downloading: validate0531.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateiJ.tfrecord 100.3%Succesfully downloaded validate0531.tfrecord 1347290 bytes.
# Successfully downloaded validate0531.tfrecord
#
#
# Downloading: validate0402.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validategE.tfrecord 100.2%Succesfully downloaded validate0402.tfrecord 1422640 bytes.
# Successfully downloaded validate0402.tfrecord
#
#
# Downloading: validate0507.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateil.tfrecord 100.5%Succesfully downloaded validate0507.tfrecord 1394519 bytes.
# Successfully downloaded validate0507.tfrecord
#
#
# Downloading: validate0912.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateoS.tfrecord 100.6%Succesfully downloaded validate0912.tfrecord 1286169 bytes.
# Successfully downloaded validate0912.tfrecord
#
#
# Downloading: validate3780.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate88.tfrecord 100.1%Succesfully downloaded validate3780.tfrecord 1309613 bytes.
# Successfully downloaded validate3780.tfrecord
#
#
# Downloading: validate3124.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateYy.tfrecord 100.3%Succesfully downloaded validate3124.tfrecord 1224817 bytes.
# Successfully downloaded validate3124.tfrecord
#
#
# Downloading: validate1976.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateF2.tfrecord 100.1%Succesfully downloaded validate1976.tfrecord 1399228 bytes.
# Successfully downloaded validate1976.tfrecord
#
#
# Downloading: validate1785.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCX.tfrecord 100.1%Succesfully downloaded validate1785.tfrecord 1465233 bytes.
# Successfully downloaded validate1785.tfrecord
#
#
# Downloading: validate3006.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateWE.tfrecord 100.2%Succesfully downloaded validate3006.tfrecord 1488696 bytes.
# Successfully downloaded validate3006.tfrecord
#
#
# Downloading: validate0678.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatek6.tfrecord 100.3%Succesfully downloaded validate0678.tfrecord 1380322 bytes.
# Successfully downloaded validate0678.tfrecord
#
#
# Downloading: validate1083.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validaterD.tfrecord 100.4%Succesfully downloaded validate1083.tfrecord 1403829 bytes.
# Successfully downloaded validate1083.tfrecord
#
#
# Downloading: validate1885.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateEz.tfrecord 100.5%Succesfully downloaded validate1885.tfrecord 1385050 bytes.
# Successfully downloaded validate1885.tfrecord
#
#
# Downloading: validate2191.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateJv.tfrecord 100.2%Succesfully downloaded validate2191.tfrecord 1234374 bytes.
# Successfully downloaded validate2191.tfrecord
#
#
# Downloading: validate3838.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate94.tfrecord 100.4%Succesfully downloaded validate3838.tfrecord 1493474 bytes.
# Successfully downloaded validate3838.tfrecord
#
#
# Downloading: validate1283.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuR.tfrecord 100.6%Succesfully downloaded validate1283.tfrecord 1352056 bytes.
# Successfully downloaded validate1283.tfrecord
#
#
# Downloading: validate0319.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatefj.tfrecord 100.1%Succesfully downloaded validate0319.tfrecord 1309635 bytes.
# Successfully downloaded validate0319.tfrecord
#
#
# Downloading: validate0367.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatef5.tfrecord 100.3%Succesfully downloaded validate0367.tfrecord 1446334 bytes.
# Successfully downloaded validate0367.tfrecord
#
#
# Downloading: validate0024.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateay.tfrecord 100.4%Succesfully downloaded validate0024.tfrecord 1516954 bytes.
# Successfully downloaded validate0024.tfrecord
#
#
# Downloading: validate0654.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatekI.tfrecord 100.4%Succesfully downloaded validate0654.tfrecord 1370935 bytes.
# Successfully downloaded validate0654.tfrecord
#
#
# Downloading: validate1775.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCN.tfrecord 100.1%Succesfully downloaded validate1775.tfrecord 1399208 bytes.
# Successfully downloaded validate1775.tfrecord
#
#
# Downloading: validate1469.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatexR.tfrecord 100.4%Succesfully downloaded validate1469.tfrecord 1337923 bytes.
# Successfully downloaded validate1469.tfrecord
#
#
# Downloading: validate0652.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatekG.tfrecord 100.0%Succesfully downloaded validate0652.tfrecord 1408656 bytes.
# Successfully downloaded validate0652.tfrecord
#
#
# Downloading: validate0084.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatebw.tfrecord 100.0%Succesfully downloaded validate0084.tfrecord 1408555 bytes.
# Successfully downloaded validate0084.tfrecord
#
#
# Downloading: validate3607.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate6l.tfrecord 100.2%Succesfully downloaded validate3607.tfrecord 1479240 bytes.
# Successfully downloaded validate3607.tfrecord
#
#
# Downloading: validate0690.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateli.tfrecord 100.1%Succesfully downloaded validate0690.tfrecord 1342622 bytes.
# Successfully downloaded validate0690.tfrecord
#
#
# Downloading: validate3074.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateXK.tfrecord 100.2%Succesfully downloaded validate3074.tfrecord 1446413 bytes.
# Successfully downloaded validate3074.tfrecord
#
#
# Downloading: validate2428.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateNk.tfrecord 100.5%Succesfully downloaded validate2428.tfrecord 1385129 bytes.
# Successfully downloaded validate2428.tfrecord
#
#
# Downloading: validate1132.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatesq.tfrecord 100.2%Succesfully downloaded validate1132.tfrecord 1234251 bytes.
# Successfully downloaded validate1132.tfrecord
#
#
# Downloading: validate2523.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateOR.tfrecord 100.0%Succesfully downloaded validate2523.tfrecord 1253143 bytes.
# Successfully downloaded validate2523.tfrecord
#
#
# Downloading: validate0721.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatelN.tfrecord 100.5%Succesfully downloaded validate0721.tfrecord 1272006 bytes.
# Successfully downloaded validate0721.tfrecord
#
#
# Downloading: validate3370.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate2w.tfrecord 100.2%Succesfully downloaded validate3370.tfrecord 1300304 bytes.
# Successfully downloaded validate3370.tfrecord
#
#
# Downloading: validate1369.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatewf.tfrecord 100.1%Succesfully downloaded validate1369.tfrecord 1309669 bytes.
# Successfully downloaded validate1369.tfrecord
#
#
# Downloading: validate1636.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateAy.tfrecord 100.5%Succesfully downloaded validate1636.tfrecord 1418089 bytes.
# Successfully downloaded validate1636.tfrecord
#
#
# Downloading: validate1600.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatezY.tfrecord 100.5%Succesfully downloaded validate1600.tfrecord 1394551 bytes.
# Successfully downloaded validate1600.tfrecord
#
#
# Downloading: validate1195.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatetr.tfrecord 100.2%Succesfully downloaded validate1195.tfrecord 1323853 bytes.
# Successfully downloaded validate1195.tfrecord
#
#
# Downloading: validate3610.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate6o.tfrecord 100.4%Succesfully downloaded validate3610.tfrecord 1394603 bytes.
# Successfully downloaded validate3610.tfrecord
#
#
# Downloading: validate3479.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate4h.tfrecord 100.5%Succesfully downloaded validate3479.tfrecord 1394458 bytes.
# Successfully downloaded validate3479.tfrecord
#
#
# Downloading: validate0171.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatecV.tfrecord 100.2%Succesfully downloaded validate0171.tfrecord 1234371 bytes.
# Successfully downloaded validate0171.tfrecord
#
#
# Downloading: validate0508.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateim.tfrecord 100.4%Succesfully downloaded validate0508.tfrecord 1427383 bytes.
# Successfully downloaded validate0508.tfrecord
#
#
# Downloading: validate3318.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate1G.tfrecord 100.1%Succesfully downloaded validate3318.tfrecord 1366189 bytes.
# Successfully downloaded validate3318.tfrecord
#
#
# Downloading: validate2690.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateRy.tfrecord 100.0%Succesfully downloaded validate2690.tfrecord 1375584 bytes.
# Successfully downloaded validate2690.tfrecord
#
#
# Downloading: validate2730.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateSc.tfrecord 100.5%Succesfully downloaded validate2730.tfrecord 1451053 bytes.
# Successfully downloaded validate2730.tfrecord
#
#
# Downloading: validate2488.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateOi.tfrecord 100.2%Succesfully downloaded validate2488.tfrecord 1356765 bytes.
# Successfully downloaded validate2488.tfrecord
#
#
# Downloading: validate3537.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate5d.tfrecord 100.6%Succesfully downloaded validate3537.tfrecord 1352059 bytes.
# Successfully downloaded validate3537.tfrecord
#
#
# Downloading: validate1697.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateBx.tfrecord 100.6%Succesfully downloaded validate1697.tfrecord 1352057 bytes.
# Successfully downloaded validate1697.tfrecord
#
#
# Downloading: validate2499.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateOt.tfrecord 100.1%Succesfully downloaded validate2499.tfrecord 1465212 bytes.
# Successfully downloaded validate2499.tfrecord
#
#
# Downloading: validate2821.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateTF.tfrecord 100.1%Succesfully downloaded validate2821.tfrecord 1399187 bytes.
# Successfully downloaded validate2821.tfrecord
#
#
# Downloading: validate0849.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatenR.tfrecord 100.3%Succesfully downloaded validate0849.tfrecord 1380324 bytes.
# Successfully downloaded validate0849.tfrecord
#
#
# Downloading: validate2912.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateU8.tfrecord 100.2%Succesfully downloaded validate2912.tfrecord 1300212 bytes.
# Successfully downloaded validate2912.tfrecord
#
#
# Downloading: validate3096.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateX6.tfrecord 100.3%Succesfully downloaded validate3096.tfrecord 1347349 bytes.
# Successfully downloaded validate3096.tfrecord
#
#
# Downloading: validate0731.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatelX.tfrecord 100.0%Succesfully downloaded validate0731.tfrecord 1286074 bytes.
# Successfully downloaded validate0731.tfrecord
#
#
# Downloading: validate0274.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateeA.tfrecord 100.2%Succesfully downloaded validate0274.tfrecord 1356838 bytes.
# Successfully downloaded validate0274.tfrecord
#
#
# Downloading: validate2574.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatePG.tfrecord 100.2%Succesfully downloaded validate2574.tfrecord 1389730 bytes.
# Successfully downloaded validate2574.tfrecord
#
#
# Downloading: validate0087.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatebz.tfrecord 100.1%Succesfully downloaded validate0087.tfrecord 1342697 bytes.
# Successfully downloaded validate0087.tfrecord
#
#
# Downloading: validate1155.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatesN.tfrecord 100.1%Succesfully downloaded validate1155.tfrecord 1432211 bytes.
# Successfully downloaded validate1155.tfrecord
#
#
# Downloading: validate1619.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateAh.tfrecord 100.3%Succesfully downloaded validate1619.tfrecord 1502779 bytes.
# Successfully downloaded validate1619.tfrecord
#
#
# Downloading: validate2032.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateGW.tfrecord 100.4%Succesfully downloaded validate2032.tfrecord 1281504 bytes.
# Successfully downloaded validate2032.tfrecord
#
#
# Downloading: validate1239.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatet9.tfrecord 100.4%Succesfully downloaded validate1239.tfrecord 1427438 bytes.
# Successfully downloaded validate1239.tfrecord
#
#
# Downloading: validate2074.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateHC.tfrecord 100.1%Succesfully downloaded validate2074.tfrecord 1488719 bytes.
# Successfully downloaded validate2074.tfrecord
#
#
# Downloading: validate0753.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatemj.tfrecord 100.4%Succesfully downloaded validate0753.tfrecord 1516907 bytes.
# Successfully downloaded validate0753.tfrecord
#
#
# Downloading: validate0637.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatekr.tfrecord 100.3%Succesfully downloaded validate0637.tfrecord 1290806 bytes.
# Successfully downloaded validate0637.tfrecord
#
#
# Downloading: validate2080.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateHI.tfrecord 100.4%Succesfully downloaded validate2080.tfrecord 1304916 bytes.
# Successfully downloaded validate2080.tfrecord
#
#
# Downloading: validate1713.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateBN.tfrecord 100.2%Succesfully downloaded validate1713.tfrecord 1300172 bytes.
# Successfully downloaded validate1713.tfrecord
#
#
# Downloading: validate0992.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateqa.tfrecord 100.0%Succesfully downloaded validate0992.tfrecord 1253185 bytes.
# Successfully downloaded validate0992.tfrecord
#
#
# Downloading: validate2449.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateNF.tfrecord 100.6%Succesfully downloaded validate2449.tfrecord 1352022 bytes.
# Successfully downloaded validate2449.tfrecord
#
#
# Downloading: validate1454.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatexC.tfrecord 100.4%Succesfully downloaded validate1454.tfrecord 1427372 bytes.
# Successfully downloaded validate1454.tfrecord
#
#
# Downloading: validate1658.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateAU.tfrecord 100.4%Succesfully downloaded validate1658.tfrecord 1370905 bytes.
# Successfully downloaded validate1658.tfrecord
#
#
# Downloading: validate2997.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateWv.tfrecord 100.1%Succesfully downloaded validate2997.tfrecord 1432182 bytes.
# Successfully downloaded validate2997.tfrecord
#
#
# Downloading: validate2050.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateHe.tfrecord 100.5%Succesfully downloaded validate2050.tfrecord 1271990 bytes.
# Successfully downloaded validate2050.tfrecord
#
#
# Downloading: validate1762.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCA.tfrecord 100.5%Succesfully downloaded validate1762.tfrecord 1361533 bytes.
# Successfully downloaded validate1762.tfrecord
#
#
# Downloading: validate3176.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateZo.tfrecord 100.1%Succesfully downloaded validate3176.tfrecord 1465192 bytes.
# Successfully downloaded validate3176.tfrecord
#
#
# Downloading: validate2249.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateKr.tfrecord 100.5%Succesfully downloaded validate2249.tfrecord 1271890 bytes.
# Successfully downloaded validate2249.tfrecord
#
#
# Downloading: validate3400.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate20.tfrecord 100.6%Succesfully downloaded validate3400.tfrecord 1262609 bytes.
# Successfully downloaded validate3400.tfrecord
#
#
# Downloading: validate3655.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate67.tfrecord 100.1%Succesfully downloaded validate3655.tfrecord 1342671 bytes.
# Successfully downloaded validate3655.tfrecord
#
#
# Downloading: validate1291.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuZ.tfrecord 100.2%Succesfully downloaded validate1291.tfrecord 1389767 bytes.
# Successfully downloaded validate1291.tfrecord
#
#
# Downloading: validate2079.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateHH.tfrecord 100.5%Succesfully downloaded validate2079.tfrecord 1507537 bytes.
# Successfully downloaded validate2079.tfrecord
#
#
# Downloading: validate2178.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateJi.tfrecord 100.2%Succesfully downloaded validate2178.tfrecord 1356881 bytes.
# Successfully downloaded validate2178.tfrecord
#
#
# Downloading: validate1271.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuF.tfrecord 100.0%Succesfully downloaded validate1271.tfrecord 1408725 bytes.
# Successfully downloaded validate1271.tfrecord
#
#
# Downloading: validate1402.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatewM.tfrecord 100.4%Succesfully downloaded validate1402.tfrecord 1517012 bytes.
# Successfully downloaded validate1402.tfrecord
#
#
# Downloading: validate2804.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateTo.tfrecord 100.2%Succesfully downloaded validate2804.tfrecord 1323806 bytes.
# Successfully downloaded validate2804.tfrecord
#
#
# Downloading: validate3787.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate9f.tfrecord 100.4%Succesfully downloaded validate3787.tfrecord 1337916 bytes.
# Successfully downloaded validate3787.tfrecord
#
#
# Downloading: validate0266.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatees.tfrecord 100.5%Succesfully downloaded validate0266.tfrecord 1182458 bytes.
# Successfully downloaded validate0266.tfrecord
#
#
# Downloading: validate0503.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateih.tfrecord 100.5%Succesfully downloaded validate0503.tfrecord 1295578 bytes.
# Successfully downloaded validate0503.tfrecord
#
#
# Downloading: validate0809.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatend.tfrecord 100.5%Succesfully downloaded validate0809.tfrecord 1304846 bytes.
# Successfully downloaded validate0809.tfrecord
#
#
# Downloading: validate2378.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateMw.tfrecord 100.5%Succesfully downloaded validate2378.tfrecord 1394501 bytes.
# Successfully downloaded validate2378.tfrecord
#
#
# Downloading: validate0974.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatepS.tfrecord 100.5%Succesfully downloaded validate0974.tfrecord 1418087 bytes.
# Successfully downloaded validate0974.tfrecord
#
#
# Downloading: validate0328.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatefs.tfrecord 100.3%Succesfully downloaded validate0328.tfrecord 1469894 bytes.
# Successfully downloaded validate0328.tfrecord
#
#
# Downloading: validate1817.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDt.tfrecord 100.0%Succesfully downloaded validate1817.tfrecord 1441597 bytes.
# Successfully downloaded validate1817.tfrecord
#
#
# Downloading: validate3590.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate54.tfrecord 100.4%Succesfully downloaded validate3590.tfrecord 1403891 bytes.
# Successfully downloaded validate3590.tfrecord
#
#
# Downloading: validate3058.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateXu.tfrecord 100.1%Succesfully downloaded validate3058.tfrecord 1309628 bytes.
# Successfully downloaded validate3058.tfrecord
#
#
# Downloading: validate0407.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validategJ.tfrecord 100.5%Succesfully downloaded validate0407.tfrecord 1295583 bytes.
# Successfully downloaded validate0407.tfrecord
#
#
# Downloading: validate0572.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatejo.tfrecord 100.3%Succesfully downloaded validate0572.tfrecord 1314508 bytes.
# Successfully downloaded validate0572.tfrecord
#
#
# Downloading: validate3026.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateWY.tfrecord 100.2%Succesfully downloaded validate3026.tfrecord 1700659 bytes.
# Successfully downloaded validate3026.tfrecord
#
#
# Downloading: validate1504.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateyq.tfrecord 100.1%Succesfully downloaded validate1504.tfrecord 1342639 bytes.
# Successfully downloaded validate1504.tfrecord
#
#
# Downloading: validate0018.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateas.tfrecord 100.2%Succesfully downloaded validate0018.tfrecord 1455687 bytes.
# Successfully downloaded validate0018.tfrecord
#
#
# Downloading: validate3594.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate58.tfrecord 100.6%Succesfully downloaded validate3594.tfrecord 1229632 bytes.
# Successfully downloaded validate3594.tfrecord
#
#
# Downloading: validate3293.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate1h.tfrecord 100.5%Succesfully downloaded validate3293.tfrecord 1272012 bytes.
# Successfully downloaded validate3293.tfrecord
#
#
# Downloading: validate3161.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateY9.tfrecord 100.5%Succesfully downloaded validate3161.tfrecord 1451083 bytes.
# Successfully downloaded validate3161.tfrecord
#
#
# Downloading: validate0812.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateng.tfrecord 100.0%Succesfully downloaded validate0812.tfrecord 1375640 bytes.
# Successfully downloaded validate0812.tfrecord
#
#
# Downloading: validate0110.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatebW.tfrecord 100.1%Succesfully downloaded validate0110.tfrecord 1366237 bytes.
# Successfully downloaded validate0110.tfrecord
#
#
# Downloading: validate3757.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate8L.tfrecord 100.5%Succesfully downloaded validate3757.tfrecord 1328524 bytes.
# Successfully downloaded validate3757.tfrecord
#
#
# Downloading: validate2216.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateJU.tfrecord 100.5%Succesfully downloaded validate2216.tfrecord 1295551 bytes.
# Successfully downloaded validate2216.tfrecord
#
#
# Downloading: validate3377.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate2D.tfrecord 100.3%Succesfully downloaded validate3377.tfrecord 1347414 bytes.
# Successfully downloaded validate3377.tfrecord
#
#
# Downloading: validate2332.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateLM.tfrecord 100.6%Succesfully downloaded validate2332.tfrecord 1319182 bytes.
# Successfully downloaded validate2332.tfrecord
#
#
# Downloading: validate0388.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validategq.tfrecord 100.1%Succesfully downloaded validate0388.tfrecord 1366288 bytes.
# Successfully downloaded validate0388.tfrecord
#
#
# Downloading: validate0383.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validategl.tfrecord 100.2%Succesfully downloaded validate0383.tfrecord 1422720 bytes.
# Successfully downloaded validate0383.tfrecord
#
#
# Downloading: validate2304.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateLk.tfrecord 100.6%Succesfully downloaded validate2304.tfrecord 1385000 bytes.
# Successfully downloaded validate2304.tfrecord
#
#
# Downloading: validate3583.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate5X.tfrecord 100.4%Succesfully downloaded validate3583.tfrecord 1370979 bytes.
# Successfully downloaded validate3583.tfrecord
#
#
# Downloading: validate3763.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate8R.tfrecord 100.2%Succesfully downloaded validate3763.tfrecord 1333204 bytes.
# Successfully downloaded validate3763.tfrecord
#
#
# Downloading: validate1670.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateA6.tfrecord 100.0%Succesfully downloaded validate1670.tfrecord 1441554 bytes.
# Successfully downloaded validate1670.tfrecord
#
#
# Downloading: validate1485.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatex7.tfrecord 100.3%Succesfully downloaded validate1485.tfrecord 1436906 bytes.
# Successfully downloaded validate1485.tfrecord
#
#
# Downloading: validate1772.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCK.tfrecord 100.2%Succesfully downloaded validate1772.tfrecord 1323795 bytes.
# Successfully downloaded validate1772.tfrecord
#
#
# Downloading: validate2293.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateK9.tfrecord 100.6%Succesfully downloaded validate2293.tfrecord 1319107 bytes.
# Successfully downloaded validate2293.tfrecord
#
#
# Downloading: validate3093.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateX3.tfrecord 100.3%Succesfully downloaded validate3093.tfrecord 1413251 bytes.
# Successfully downloaded validate3093.tfrecord
#
#
# Downloading: validate2447.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateND.tfrecord 100.1%Succesfully downloaded validate2447.tfrecord 1366153 bytes.
# Successfully downloaded validate2447.tfrecord
#
#
# Downloading: validate3792.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate9k.tfrecord 100.5%Succesfully downloaded validate3792.tfrecord 1361502 bytes.
# Successfully downloaded validate3792.tfrecord
#
#
# Downloading: validate3622.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate6A.tfrecord 100.5%Succesfully downloaded validate3622.tfrecord 1385057 bytes.
# Successfully downloaded validate3622.tfrecord
#
#
# Downloading: validate1240.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateua.tfrecord 100.4%Succesfully downloaded validate1240.tfrecord 1460421 bytes.
# Successfully downloaded validate1240.tfrecord
#
#
# Downloading: validate1644.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateAG.tfrecord 100.1%Succesfully downloaded validate1644.tfrecord 1366217 bytes.
# Successfully downloaded validate1644.tfrecord
#
#
# Downloading: validate3117.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateYr.tfrecord 100.0%Succesfully downloaded validate3117.tfrecord 1375600 bytes.
# Successfully downloaded validate3117.tfrecord
#
#
# Downloading: validate1740.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCe.tfrecord 100.3%Succesfully downloaded validate1740.tfrecord 1436837 bytes.
# Successfully downloaded validate1740.tfrecord
#
#
# Downloading: validate1673.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateA9.tfrecord 100.5%Succesfully downloaded validate1673.tfrecord 1394485 bytes.
# Successfully downloaded validate1673.tfrecord
#
#
# Downloading: validate1824.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDA.tfrecord 100.5%Succesfully downloaded validate1824.tfrecord 1451087 bytes.
# Successfully downloaded validate1824.tfrecord
#
#
# Downloading: validate2717.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateRZ.tfrecord 100.5%Succesfully downloaded validate2717.tfrecord 1385075 bytes.
# Successfully downloaded validate2717.tfrecord
#
#
# Downloading: validate1804.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDg.tfrecord 100.5%Succesfully downloaded validate1804.tfrecord 1361505 bytes.
# Successfully downloaded validate1804.tfrecord
#
#
# Downloading: validate1571.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatezv.tfrecord 100.6%Succesfully downloaded validate1571.tfrecord 1140042 bytes.
# Successfully downloaded validate1571.tfrecord
#
#
# Downloading: validate3489.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate4r.tfrecord 100.6%Succesfully downloaded validate3489.tfrecord 1229633 bytes.
# Successfully downloaded validate3489.tfrecord
#
#
# Downloading: validate2858.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateUg.tfrecord 100.5%Succesfully downloaded validate2858.tfrecord 1483921 bytes.
# Successfully downloaded validate2858.tfrecord
#
#
# Downloading: validate2087.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateHP.tfrecord 100.2%Succesfully downloaded validate2087.tfrecord 1422769 bytes.
# Successfully downloaded validate2087.tfrecord
#
#
# Downloading: validate1699.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateBz.tfrecord 100.5%Succesfully downloaded validate1699.tfrecord 1271975 bytes.
# Successfully downloaded validate1699.tfrecord
#
#
# Downloading: validate1975.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateF1.tfrecord 100.2%Succesfully downloaded validate1975.tfrecord 1488658 bytes.
# Successfully downloaded validate1975.tfrecord
#
#
# Downloading: validate0038.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateaM.tfrecord 100.4%Succesfully downloaded validate0038.tfrecord 1370966 bytes.
# Successfully downloaded validate0038.tfrecord
#
#
# Downloading: validate3240.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate0q.tfrecord 100.4%Succesfully downloaded validate3240.tfrecord 1403843 bytes.
# Successfully downloaded validate3240.tfrecord
#
#
# Downloading: validate3796.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate9o.tfrecord 100.2%Succesfully downloaded validate3796.tfrecord 1333226 bytes.
# Successfully downloaded validate3796.tfrecord
#
#
# Downloading: validate2870.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateUs.tfrecord 100.3%Succesfully downloaded validate2870.tfrecord 1436909 bytes.
# Successfully downloaded validate2870.tfrecord
#
#
# Downloading: validate0149.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatecz.tfrecord 100.1%Succesfully downloaded validate0149.tfrecord 1432151 bytes.
# Successfully downloaded validate0149.tfrecord
#
#
# Downloading: validate0062.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateba.tfrecord 100.4%Succesfully downloaded validate0062.tfrecord 1304976 bytes.
# Successfully downloaded validate0062.tfrecord
#
#
# Downloading: validate2103.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateH5.tfrecord 100.2%Succesfully downloaded validate2103.tfrecord 1389725 bytes.
# Successfully downloaded validate2103.tfrecord
#
#
# Downloading: validate3710.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate70.tfrecord 100.3%Succesfully downloaded validate3710.tfrecord 1469803 bytes.
# Successfully downloaded validate3710.tfrecord
#
#
# Downloading: validate2848.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateT6.tfrecord 100.1%Succesfully downloaded validate2848.tfrecord 1342645 bytes.
# Successfully downloaded validate2848.tfrecord
#
#
# Downloading: validate3685.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate7B.tfrecord 100.1%Succesfully downloaded validate3685.tfrecord 1342603 bytes.
# Successfully downloaded validate3685.tfrecord
#
#
# Downloading: validate0359.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatefX.tfrecord 100.3%Succesfully downloaded validate0359.tfrecord 1413278 bytes.
# Successfully downloaded validate0359.tfrecord
#
#
# Downloading: validate2288.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateK4.tfrecord 100.3%Succesfully downloaded validate2288.tfrecord 1380332 bytes.
# Successfully downloaded validate2288.tfrecord
#
#
# Downloading: validate3070.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateXG.tfrecord 100.1%Succesfully downloaded validate3070.tfrecord 1276732 bytes.
# Successfully downloaded validate3070.tfrecord
#
#
# Downloading: validate2622.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQs.tfrecord 100.4%Succesfully downloaded validate2622.tfrecord 1427532 bytes.
# Successfully downloaded validate2622.tfrecord
#
#
# Downloading: validate0827.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatenv.tfrecord 100.1%Succesfully downloaded validate0827.tfrecord 1154202 bytes.
# Successfully downloaded validate0827.tfrecord
#
#
# Downloading: validate0249.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateeb.tfrecord 100.2%Succesfully downloaded validate0249.tfrecord 1479191 bytes.
# Successfully downloaded validate0249.tfrecord
#
#
# Downloading: validate0389.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validategr.tfrecord 100.3%Succesfully downloaded validate0389.tfrecord 1413308 bytes.
# Successfully downloaded validate0389.tfrecord
#
#
# Downloading: validate2355.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateL9.tfrecord 100.4%Succesfully downloaded validate2355.tfrecord 1403872 bytes.
# Successfully downloaded validate2355.tfrecord
#
#
# Downloading: validate1282.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuQ.tfrecord 100.5%Succesfully downloaded validate1282.tfrecord 1483963 bytes.
# Successfully downloaded validate1282.tfrecord
#
#
# Downloading: validate1265.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuz.tfrecord 100.3%Succesfully downloaded validate1265.tfrecord 1413403 bytes.
# Successfully downloaded validate1265.tfrecord
#
#
# Downloading: validate1634.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateAw.tfrecord 100.1%Succesfully downloaded validate1634.tfrecord 1465182 bytes.
# Successfully downloaded validate1634.tfrecord
#
#
# Downloading: validate2918.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateVe.tfrecord 100.0%Succesfully downloaded validate2918.tfrecord 1286063 bytes.
# Successfully downloaded validate2918.tfrecord
#
#
# Downloading: validate1803.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDf.tfrecord 100.3%Succesfully downloaded validate1803.tfrecord 1380316 bytes.
# Successfully downloaded validate1803.tfrecord
#
#
# Downloading: validate3813.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate9F.tfrecord 100.0%Succesfully downloaded validate3813.tfrecord 1408545 bytes.
# Successfully downloaded validate3813.tfrecord
#
#
# Downloading: validate1627.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateAp.tfrecord 100.5%Succesfully downloaded validate1627.tfrecord 1450989 bytes.
# Successfully downloaded validate1627.tfrecord
#
#
# Downloading: validate2421.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateNd.tfrecord 100.6%Succesfully downloaded validate2421.tfrecord 1319087 bytes.
# Successfully downloaded validate2421.tfrecord
#
#
# Downloading: validate0677.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatek5.tfrecord 100.3%Succesfully downloaded validate0677.tfrecord 1380378 bytes.
# Successfully downloaded validate0677.tfrecord
#
#
# Downloading: validate2587.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatePT.tfrecord 100.2%Succesfully downloaded validate2587.tfrecord 1389768 bytes.
# Successfully downloaded validate2587.tfrecord
#
#
# Downloading: validate0232.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatedU.tfrecord 100.3%Succesfully downloaded validate0232.tfrecord 1347365 bytes.
# Successfully downloaded validate0232.tfrecord
#
#
# Downloading: validate3302.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate1q.tfrecord 100.4%Succesfully downloaded validate3302.tfrecord 1493478 bytes.
# Successfully downloaded validate3302.tfrecord
#
#
# Downloading: validate1100.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validaterU.tfrecord 100.0%Succesfully downloaded validate1100.tfrecord 1531152 bytes.
# Successfully downloaded validate1100.tfrecord
#
#
# Downloading: validate0204.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateds.tfrecord 100.4%Succesfully downloaded validate0204.tfrecord 1403899 bytes.
# Successfully downloaded validate0204.tfrecord
#
#
# Downloading: validate1864.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateEe.tfrecord 100.5%Succesfully downloaded validate1864.tfrecord 1451004 bytes.
# Successfully downloaded validate1864.tfrecord
#
#
# Downloading: validate2143.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateIJ.tfrecord 100.3%Succesfully downloaded validate2143.tfrecord 1413291 bytes.
# Successfully downloaded validate2143.tfrecord
#
#
# Downloading: validate2577.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatePJ.tfrecord 100.1%Succesfully downloaded validate2577.tfrecord 1465169 bytes.
# Successfully downloaded validate2577.tfrecord
#
#
# Downloading: validate0649.tfrecord
# ...
# Successfully downloaded validate3336.tfrecord
#
#
# Downloading: validate0332.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatefw.tfrecord 100.2%Succesfully downloaded validate0332.tfrecord 1455701 bytes.
# Successfully downloaded validate0332.tfrecord
#
#
# Downloading: validate1760.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCy.tfrecord 100.4%Succesfully downloaded validate1760.tfrecord 1281380 bytes.
# Successfully downloaded validate1760.tfrecord
#
#
# Downloading: validate2885.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateUH.tfrecord 100.6%Succesfully downloaded validate2885.tfrecord 1352171 bytes.
# Successfully downloaded validate2885.tfrecord
#
#
# Downloading: validate1188.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatetk.tfrecord 100.3%Succesfully downloaded validate1188.tfrecord 1168293 bytes.
# Successfully downloaded validate1188.tfrecord
#
#
# Downloading: validate3800.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate9s.tfrecord 100.5%Succesfully downloaded validate3800.tfrecord 1295572 bytes.
# Successfully downloaded validate3800.tfrecord
#
#
# Downloading: validate3359.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate2l.tfrecord 100.4%Succesfully downloaded validate3359.tfrecord 1370920 bytes.
# Successfully downloaded validate3359.tfrecord
#
#
# Downloading: validate2350.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateL4.tfrecord 100.3%Succesfully downloaded validate2350.tfrecord 1347325 bytes.
# Successfully downloaded validate2350.tfrecord
#
#
# Downloading: validate1289.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuX.tfrecord 100.5%Succesfully downloaded validate1289.tfrecord 1361464 bytes.
# Successfully downloaded validate1289.tfrecord
#
#
# Downloading: validate3497.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate4z.tfrecord 100.2%Succesfully downloaded validate3497.tfrecord 1488644 bytes.
# Successfully downloaded validate3497.tfrecord
#
#
# Downloading: validate3587.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate51.tfrecord 100.5%Succesfully downloaded validate3587.tfrecord 1328463 bytes.
# Successfully downloaded validate3587.tfrecord
#
#
# Downloading: validate3210.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateZW.tfrecord 100.4%Succesfully downloaded validate3210.tfrecord 1337851 bytes.
# Successfully downloaded validate3210.tfrecord
#
#
# Downloading: validate0210.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatedy.tfrecord 100.5%Succesfully downloaded validate0210.tfrecord 1361504 bytes.
# Successfully downloaded validate0210.tfrecord
#
#
# Downloading: validate1847.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDX.tfrecord 100.3%Succesfully downloaded validate1847.tfrecord 1257806 bytes.
# Successfully downloaded validate1847.tfrecord
#
#
# Downloading: validate3720.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate8a.tfrecord 100.2%Succesfully downloaded validate3720.tfrecord 1300296 bytes.
# Successfully downloaded validate3720.tfrecord
#
#
# Downloading: validate3788.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate9g.tfrecord 100.2%Succesfully downloaded validate3788.tfrecord 1389830 bytes.
# Successfully downloaded validate3788.tfrecord
#
#
# Downloading: validate0512.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateiq.tfrecord 100.2%Succesfully downloaded validate0512.tfrecord 1356850 bytes.
# Successfully downloaded validate0512.tfrecord
#
#
# Downloading: validate0765.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatemv.tfrecord 100.1%Succesfully downloaded validate0765.tfrecord 1432155 bytes.
# Successfully downloaded validate0765.tfrecord
#
#
# Downloading: validate2660.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQ4.tfrecord 100.6%Succesfully downloaded validate2660.tfrecord 1196614 bytes.
# Successfully downloaded validate2660.tfrecord
#
#
# Downloading: validate2154.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateIU.tfrecord 100.1%Succesfully downloaded validate2154.tfrecord 1333300 bytes.
# Successfully downloaded validate2154.tfrecord
#
#
# Downloading: validate2251.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateKt.tfrecord 100.5%Succesfully downloaded validate2251.tfrecord 1328507 bytes.
# Successfully downloaded validate2251.tfrecord
#
#
# Downloading: validate0457.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatehx.tfrecord 100.5%Succesfully downloaded validate0457.tfrecord 1328543 bytes.
# Successfully downloaded validate0457.tfrecord
#
#
# Downloading: validate1834.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDK.tfrecord 100.4%Succesfully downloaded validate1834.tfrecord 1304984 bytes.
# Successfully downloaded validate1834.tfrecord
#
#
# Downloading: validate3158.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateY6.tfrecord 100.3%Succesfully downloaded validate3158.tfrecord 1502885 bytes.
# Successfully downloaded validate3158.tfrecord
#
#
# Downloading: validate0571.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatejn.tfrecord 100.1%Succesfully downloaded validate0571.tfrecord 1342709 bytes.
# Successfully downloaded validate0571.tfrecord
#
#
# Downloading: validate2042.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateG6.tfrecord 100.5%Succesfully downloaded validate2042.tfrecord 1328442 bytes.
# Successfully downloaded validate2042.tfrecord
#
#
# Downloading: validate3211.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateZX.tfrecord 100.4%Succesfully downloaded validate3211.tfrecord 1427442 bytes.
# Successfully downloaded validate3211.tfrecord
#
#
# Downloading: validate3090.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateX0.tfrecord 100.3%Succesfully downloaded validate3090.tfrecord 1347318 bytes.
# Successfully downloaded validate3090.tfrecord
#
#
# Downloading: validate0893.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateoz.tfrecord 100.2%Succesfully downloaded validate0893.tfrecord 1455762 bytes.
# Successfully downloaded validate0893.tfrecord
#
#
# Downloading: validate0411.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validategN.tfrecord 100.1%Succesfully downloaded validate0411.tfrecord 1342623 bytes.
# Successfully downloaded validate0411.tfrecord
#
#
# Downloading: validate2320.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateLA.tfrecord 100.2%Succesfully downloaded validate2320.tfrecord 1333229 bytes.
# Successfully downloaded validate2320.tfrecord
#
#
# Downloading: validate1946.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateFy.tfrecord 100.2%Succesfully downloaded validate1946.tfrecord 1234296 bytes.
# Successfully downloaded validate1946.tfrecord
#
#
# Downloading: validate0291.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateeR.tfrecord 100.2%Succesfully downloaded validate0291.tfrecord 1488615 bytes.
# Successfully downloaded validate0291.tfrecord
#
#
# Downloading: validate2758.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateSE.tfrecord 100.5%Succesfully downloaded validate2758.tfrecord 1385084 bytes.
# Successfully downloaded validate2758.tfrecord
#
#
# Downloading: validate3135.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateYJ.tfrecord 100.4%Succesfully downloaded validate3135.tfrecord 1281386 bytes.
# Successfully downloaded validate3135.tfrecord
#
#
# Downloading: validate0766.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatemw.tfrecord 100.2%Succesfully downloaded validate0766.tfrecord 1455752 bytes.
# Successfully downloaded validate0766.tfrecord
#
#
# Downloading: validate2363.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateMh.tfrecord 100.5%Succesfully downloaded validate2363.tfrecord 1361491 bytes.
# Successfully downloaded validate2363.tfrecord
#
#
# Downloading: validate0351.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatefP.tfrecord 100.5%Succesfully downloaded validate0351.tfrecord 1239098 bytes.
# Successfully downloaded validate0351.tfrecord
#
#
# Downloading: validate1297.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateu5.tfrecord 100.3%Succesfully downloaded validate1297.tfrecord 1323793 bytes.
# Successfully downloaded validate1297.tfrecord
#
#
# Downloading: validate2606.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQc.tfrecord 100.3%Succesfully downloaded validate2606.tfrecord 1347291 bytes.
# Successfully downloaded validate2606.tfrecord
#
#
# Downloading: validate0140.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatecq.tfrecord 100.2%Succesfully downloaded validate0140.tfrecord 1333195 bytes.
# Successfully downloaded validate0140.tfrecord
#
#
# Downloading: validate3378.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate2E.tfrecord 100.1%Succesfully downloaded validate3378.tfrecord 1276837 bytes.
# Successfully downloaded validate3378.tfrecord
#
#
# Downloading: validate0046.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateaU.tfrecord 100.5%Succesfully downloaded validate0046.tfrecord 1394505 bytes.
# Successfully downloaded validate0046.tfrecord
#
#
# Downloading: validate1426.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatexa.tfrecord 100.3%Succesfully downloaded validate1426.tfrecord 1436815 bytes.
# Successfully downloaded validate1426.tfrecord
#
#
# Downloading: validate1782.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateCU.tfrecord 100.2%Succesfully downloaded validate1782.tfrecord 1201294 bytes.
# Successfully downloaded validate1782.tfrecord
#
#
# Downloading: validate3679.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate7v.tfrecord 100.2%Succesfully downloaded validate3679.tfrecord 1422735 bytes.
# Successfully downloaded validate3679.tfrecord
#
#
# Downloading: validate1844.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateDU.tfrecord 100.0%Succesfully downloaded validate1844.tfrecord 1408586 bytes.
# Successfully downloaded validate1844.tfrecord
#
#
# Downloading: validate3276.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate00.tfrecord 100.3%Succesfully downloaded validate3276.tfrecord 1469972 bytes.
# Successfully downloaded validate3276.tfrecord
#
#
# Downloading: validate2620.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQq.tfrecord 100.2%Succesfully downloaded validate2620.tfrecord 1300219 bytes.
# Successfully downloaded validate2620.tfrecord
#
#
# Downloading: validate3533.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate49.tfrecord 100.6%Succesfully downloaded validate3533.tfrecord 1262632 bytes.
# Successfully downloaded validate3533.tfrecord
#
#
# Downloading: validate3552.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validate5s.tfrecord 100.4%Succesfully downloaded validate3552.tfrecord 1460446 bytes.
# Successfully downloaded validate3552.tfrecord
#
#
# Downloading: validate2024.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateGO.tfrecord 100.5%Succesfully downloaded validate2024.tfrecord 1418049 bytes.
# Successfully downloaded validate2024.tfrecord
#
#
# Downloading: validate0261.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateen.tfrecord 100.1%Succesfully downloaded validate0261.tfrecord 1399183 bytes.
# Successfully downloaded validate0261.tfrecord
#
#
# Downloading: validate1237.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatet7.tfrecord 100.5%Succesfully downloaded validate1237.tfrecord 1361437 bytes.
# Successfully downloaded validate1237.tfrecord
#
#
# Downloading: validate2112.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateIe.tfrecord 100.1%Succesfully downloaded validate2112.tfrecord 1309701 bytes.
# Successfully downloaded validate2112.tfrecord
#
#
# Downloading: validate2147.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateIN.tfrecord 100.1%Succesfully downloaded validate2147.tfrecord 1342618 bytes.
# Successfully downloaded validate2147.tfrecord
#
#
# Downloading: validate0467.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatehH.tfrecord 100.2%Succesfully downloaded validate0467.tfrecord 1389800 bytes.
# Successfully downloaded validate0467.tfrecord
#
#
# Downloading: validate0944.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatepo.tfrecord 100.4%Succesfully downloaded validate0944.tfrecord 1338013 bytes.
# Successfully downloaded validate0944.tfrecord
#
#
# Downloading: validate1517.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateyD.tfrecord 100.3%Succesfully downloaded validate1517.tfrecord 1446343 bytes.
# Successfully downloaded validate1517.tfrecord
#
#
# Downloading: validate0474.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatehO.tfrecord 100.5%Succesfully downloaded validate0474.tfrecord 1394420 bytes.
# Successfully downloaded validate0474.tfrecord
#
#
# Downloading: validate0538.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateiQ.tfrecord 100.5%Succesfully downloaded validate0538.tfrecord 1418058 bytes.
# Successfully downloaded validate0538.tfrecord
#
#
# Downloading: validate2284.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateK0.tfrecord 100.4%Succesfully downloaded validate2284.tfrecord 1403844 bytes.
# Successfully downloaded validate2284.tfrecord
#
#
# Downloading: validate0803.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatem7.tfrecord 100.4%Succesfully downloaded validate0803.tfrecord 1403909 bytes.
# Successfully downloaded validate0803.tfrecord
#
#
# Downloading: validate1266.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateuA.tfrecord 100.3%Succesfully downloaded validate1266.tfrecord 1413345 bytes.
# Successfully downloaded validate1266.tfrecord
#
#
# Downloading: validate3051.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateXn.tfrecord 100.0%Succesfully downloaded validate3051.tfrecord 1408576 bytes.
# Successfully downloaded validate3051.tfrecord
#
#
# Downloading: validate1891.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateEF.tfrecord 100.4%Succesfully downloaded validate1891.tfrecord 1281454 bytes.
# Successfully downloaded validate1891.tfrecord
#
#
# Downloading: validate2614.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validateQk.tfrecord 100.2%Succesfully downloaded validate2614.tfrecord 1300227 bytes.
# Successfully downloaded validate2614.tfrecord
#
#
# Downloading: validate0577.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatejt.tfrecord 100.3%Succesfully downloaded validate0577.tfrecord 1224874 bytes.
# Successfully downloaded validate0577.tfrecord
#
#
# Downloading: validate0699.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatelr.tfrecord 100.2%Succesfully downloaded validate0699.tfrecord 1422862 bytes.
# Successfully downloaded validate0699.tfrecord
#
#
# Downloading: validate2572.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatePE.tfrecord 100.3%Succesfully downloaded validate2572.tfrecord 1347289 bytes.
# Successfully downloaded validate2572.tfrecord
#
#
# Downloading: validate1226.tfrecord
# >> Downloading http://asia.data.yt8m.org/2/video/validate/validatetW.tfrecord 100.0%Succesfully downloaded validate1226.tfrecord 1286141 bytes.
# Successfully downloaded validate1226.tfrecord
#
#
# All done. No more files to download.

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
from torchdata.datapipes.iter import FileLister, FileOpener
datapipe1 = FileLister(".", "*.tfrecord")
datapipe2 = FileOpener(datapipe1, mode="b")
dp = datapipe2.load_from_tfrecord()

# %%
dp
# Out:
# TFRecordLoaderIterDataPipe

# %%
type(dp)
# Out:
# torchdata.datapipes.iter.util.tfrecordloader.TFRecordLoaderIterDataPipe

# %%
dp_iter = iter(dp)


first_dp = next(dp_iter)
second_dp = next(dp_iter)
third_dp = next(dp_iter)


print("first_dp : ",first_dp)
print("second_dp : ",second_dp)
print("third_dp : ",third_dp)
# Out:
# first_dp :  {'mean_audio': tensor([ 0.9267,  0.4857,  0.8598,  0.3353, -0.1296,  0.0260,  0.7640,  0.5293,
#         -1.4497,  0.8693, -0.7343,  0.6396,  0.5051,  0.8306, -0.6718, -0.7527,
#         -0.4628, -0.3049, -1.0142,  0.4080,  0.5704, -0.6675, -1.1520, -1.1420,
#         -0.9271,  1.2328, -0.3878, -0.4780, -0.3206,  0.2193,  0.4585,  0.0176,
#         -0.9125, -0.4352,  0.1248, -0.7745,  0.6508,  0.8498, -0.7571,  0.4497,
#          0.3109, -0.8420,  0.1525,  0.3093,  0.5593, -0.8665,  0.8311, -0.2873,
#         -0.1012, -0.4112,  0.0880, -0.9859, -0.6037,  0.5276, -0.0525,  0.7347,
#          0.6046,  0.6086, -1.1697, -0.1417, -0.5101, -0.5204, -0.3758, -0.6102,
#         -1.1584, -0.6985, -0.7198,  0.7707,  0.0710, -0.3478, -0.5245,  0.6103,
#         -0.0502,  0.1651,  0.1008,  0.6937, -0.0585, -0.5083, -0.2555,  0.6085,
#          0.0367, -0.3302,  0.0837, -0.5465, -0.2298, -0.5779, -1.0859,  0.3489,
#          0.4608, -0.1158,  0.1177, -0.1882, -0.6757,  0.1752,  0.5754,  0.6299,
#         -0.5371,  0.2479, -0.8791,  0.0675,  0.0272, -0.9007,  0.5197,  0.5508,
#          0.3159, -1.0556,  0.3789,  0.3619, -0.7118,  0.6953,  0.6991,  0.5884,
#         -0.2952, -0.7939, -0.4609, -0.1576, -0.6818, -0.1124,  0.7978, -0.1798,
#         -0.8186,  0.1037,  0.2786,  0.2035,  0.0131,  0.3619,  0.9646, -0.2461]), 'id': [b'02aa'], 'mean_rgb': tensor([-0.7816,  0.1050,  1.5639,  ...,  0.1859,  0.1755,  0.3666]), 'labels': tensor([ 3,  4,  9, 34])}
# second_dp :  {'id': [b'p7aa'], 'labels': tensor([ 0,  1, 36, 94]), 'mean_rgb': tensor([ 0.9244,  0.2899, -0.4131,  ..., -0.0967,  0.2723,  0.1335]), 'mean_audio': tensor([-1.5404e+00, -3.3395e-01, -8.4110e-01,  1.6823e+00, -1.0154e+00,
#         -7.2229e-01, -1.1405e+00, -9.6161e-01, -1.2781e+00,  1.0249e+00,
#          1.1174e+00,  1.6075e-01,  1.3189e+00,  9.5339e-01, -1.7110e+00,
#          2.2228e-01, -1.4085e-03,  4.9525e-01, -1.6527e-01, -1.4813e+00,
#         -2.0554e-01,  5.8593e-01, -6.0448e-01, -1.1028e+00,  1.2194e+00,
#         -6.0692e-01, -3.7942e-01,  1.6126e+00,  4.8206e-01, -7.7067e-01,
#          2.6324e-01, -1.1412e+00,  4.6796e-01,  1.2481e+00, -1.3443e+00,
#         -5.3888e-01, -3.1837e-01, -1.3366e+00,  6.9403e-01,  9.9916e-02,
#          8.8889e-01,  1.0305e+00, -6.2801e-01,  2.6377e-01,  9.0802e-01,
#         -7.2934e-01, -5.0136e-01, -7.3268e-01,  9.3993e-01,  1.1632e+00,
#          4.6176e-01, -6.2282e-01, -4.7237e-01, -8.0989e-01, -1.0486e+00,
#         -7.1275e-01, -1.1147e+00,  5.8598e-01,  1.4273e+00,  1.2429e-01,
#         -4.2176e-01,  7.4072e-01, -7.5848e-01,  1.0334e+00,  4.4300e-01,
#         -3.9076e-01, -1.4337e+00,  4.1295e-01, -1.2017e-01, -1.2383e+00,
#         -7.1519e-01, -8.5658e-01, -5.3771e-01, -4.6060e-01, -1.1614e-01,
#          6.7559e-01,  7.3510e-01,  6.1496e-02, -1.6262e-01,  5.2466e-01,
#         -5.8922e-01,  1.2074e+00,  1.2381e+00,  8.7776e-01,  1.2323e-01,
#         -9.8026e-01, -1.4863e+00,  6.1025e-01, -3.6495e-01,  7.0437e-01,
#         -1.2262e+00,  4.4115e-01, -1.1325e+00, -4.7173e-01,  6.1195e-01,
#         -1.7761e-01,  1.3597e+00,  7.8794e-01, -1.2132e+00, -7.4036e-01,
#          1.4416e+00,  4.2482e-01,  2.4618e-01, -7.7380e-01,  4.7331e-01,
#         -9.0242e-01, -1.3030e+00,  2.5577e-01, -1.0704e+00, -4.1492e-01,
#         -4.2267e-02, -9.2520e-01, -8.0575e-01,  6.1958e-01,  7.2355e-01,
#         -1.0467e+00, -1.1339e+00,  3.1046e-01,  1.0299e-01, -1.1915e+00,
#          5.7681e-01,  1.4480e+00, -6.5536e-01,  3.4814e-01,  8.3500e-01,
#         -2.8085e-01,  1.6314e+00, -7.7269e-01])}
# third_dp :  {'id': [b'tHaa'], 'mean_rgb': tensor([-0.2179,  0.7436,  1.6226,  ..., -0.7556,  0.2385,  0.1294]), 'mean_audio': tensor([ 1.3525,  1.3499,  1.2870, -0.0082, -0.2120, -0.1990, -0.6860, -0.4840,
#         -1.7163,  0.6225, -1.0139,  1.4358,  0.3846,  1.1194,  0.1971, -0.1036,
#          0.1508, -0.0253, -0.5913,  1.6133, -0.3460,  0.8439,  0.5704,  0.8493,
#          0.1326, -0.1330,  0.3716, -0.7811, -0.0892,  0.2659, -0.6503, -0.7034,
#          1.1531,  0.7677, -0.8589, -0.0047, -0.4649,  0.2302,  0.1553,  0.3963,
#         -0.4029,  0.1046,  0.7639,  0.8671,  0.6714,  0.4656,  0.7799, -0.5439,
#          0.1290, -0.4673,  0.8606, -0.6476,  0.4137,  0.5045,  0.2211,  0.6100,
#          0.0789,  0.4957, -1.0667,  0.1867,  0.1709,  0.2747,  0.0432,  0.6145,
#          0.2769,  1.0277,  0.2536, -0.5363,  0.0747, -0.2048, -0.2148, -0.2307,
#          0.2890, -0.0425,  0.4718, -0.1979,  0.5603,  0.1364,  0.1852,  0.9177,
#          0.3129, -0.1624, -0.1335, -0.7482,  0.1835, -0.6884,  0.5590,  0.3495,
#          0.2892, -0.0827, -0.1780,  0.2901, -0.7921, -0.6297,  0.0347, -0.5261,
#          0.5947, -0.6305, -0.1746,  0.1606,  0.5281, -0.2156, -0.8059, -0.1789,
#          0.1523,  0.1234,  0.2095,  0.5319,  0.4986,  0.2789,  0.3801,  0.0406,
#         -0.3669, -0.0217,  0.1724,  0.8799,  0.0934,  0.5084,  0.6196,  0.4474,
#         -0.4106,  0.0746, -0.7022,  0.4147,  0.3282, -0.4658,  1.0853, -0.5780]), 'labels': tensor([3, 4, 6])}

# %%
# 이진 인코딩을 위한 함수 정의
def binary_encoding(label, num_classes):
    binary_label = torch.zeros(num_classes)  # 모든 값을 0으로 초기화
    for l in label:
        binary_label[l] = 1  # 해당하는 클래스의 인덱스에 1 설정
    return binary_label
# Out:
# Multi-Class Label: [1, 2, 19], Binary Encoded: tensor([0., 1., 1.,  ..., 0., 0., 0.])
# Multi-Class Label: [1, 56, 892, 3001], Binary Encoded: tensor([0., 1., 0.,  ..., 0., 0., 0.])
# Multi-Class Label: [5, 76, 774], Binary Encoded: tensor([0., 0., 0.,  ..., 0., 0., 0.])

# %%
import torch
from torch.utils.data import DataLoader, Dataset
import torchdata


# 데이터로더 생성
batch_size = 128

from torch.utils.data import DataLoader

def collate_fn(batch):
    collated_batch = {
        'mean_audio': torch.stack([torch.tensor(data['mean_audio']).clone().detach() for data in batch]),
        'mean_rgb': torch.stack([torch.tensor(data['mean_rgb']).clone().detach() for data in batch]),
        'labels': torch.stack([binary_encoding(data['labels'], num_classes) for data in batch])
    }
    return collated_batch

# DataLoader 생성 시 collate_fn 매개변수에 collate_fn 함수 지정
dataloader = DataLoader(dp, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/graph_settings.py:103: UserWarning: `shuffle=True` was set, but the datapipe does not contain a `Shuffler`. Adding one at the end. Be aware that the default buffer size might not be sufficient for your task.
#   warnings.warn(

# %% [markdown]
# ### 모델 생성 및 학습

# %%
import torch
import torch.nn as nn

class SimpleMLP(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(SimpleMLP, self).__init__()
        self.fc1 = nn.Linear(input_size * 2, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, mean_audio, mean_rgb):
        # 입력 데이터를 하나의 텐서로 결합
        combined_input = torch.cat((mean_audio, mean_rgb), dim=1)
        out = self.fc1(combined_input)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
cnt = 0
for batch in dataloader:
    cnt= cnt + 1

print("배치 수 :", cnt)
# Out:
# <ipython-input-5-a60106772ac6>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'mean_audio': torch.stack([torch.tensor(data['mean_audio']).clone().detach() for data in batch]),
# <ipython-input-5-a60106772ac6>:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'mean_rgb': torch.stack([torch.tensor(data['mean_rgb']).clone().detach() for data in batch]),
# 배치 수 : 8691

# %%
# 모델, 손실 함수, 최적화기 설정
input_size = 576  # 입력 피처의 크기 (mean_audio와 mean_rgb의 크기에 따라 달라질 수 있음)
hidden_size = 4  # 은닉층의 크기
num_classes = 3862  # 클래스의 개수

model = SimpleMLP(input_size, hidden_size, num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 모델 학습
num_epochs = 10
for epoch in range(num_epochs):
    total_loss = 0
    for batch in dataloader:
        # 데이터 및 레이블 가져오기
        mean_audio, mean_rgb, labels = batch['mean_audio'], batch['mean_rgb'], batch['labels']

        # 순전파 + 역전파 + 최적화
        optimizer.zero_grad()
        outputs = model(mean_audio, mean_rgb)  # 모델에 입력 데이터 전달
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # 에폭마다 손실 출력
    print(f"Epoch {epoch+1}, Loss: {total_loss / cnt}")
# Out:
# <ipython-input-5-a60106772ac6>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'mean_audio': torch.stack([torch.tensor(data['mean_audio']).clone().detach() for data in batch]),
# <ipython-input-5-a60106772ac6>:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'mean_rgb': torch.stack([torch.tensor(data['mean_rgb']).clone().detach() for data in batch]),
# Epoch 1, Loss: 13.61286085267265
# Epoch 2, Loss: 12.055239590192853
# Epoch 3, Loss: 11.804041288703074
# Epoch 4, Loss: 11.65611647034306
# Epoch 5, Loss: 11.564100341985613
# Epoch 6, Loss: 11.503540342030488
# Epoch 7, Loss: 11.459672722768735
# Epoch 8, Loss: 11.426715806608383
# Epoch 9, Loss: 11.400802133437502
# Epoch 10, Loss: 11.381092849637515
